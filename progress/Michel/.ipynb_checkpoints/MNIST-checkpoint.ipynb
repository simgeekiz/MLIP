# %% [markdown]
# # MNIST - Digit Recognizer

# %% [markdown]
# Notebook to classify the MNIST network.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import time
import os
from imgaug import augmenters as iaa

from IPython import display

from sklearn import svm
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from keras.models import Model, load_model
from keras.layers import Input, Dense, Dropout, Flatten, BatchNormalization, Activation, LeakyReLU
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils

from toolkit import mnist_to_pdseries, write_results

# %% [markdown]
# ## Set globals

# %%
DATA_FOLDER = '../Joan/data/'
RESULTS_FOLDER = '../Michel/results/'

# %% [markdown]
# ## Read data

# %%
X_train, y_train, X_test = mnist_to_pdseries(DATA_FOLDER)
print('Size X_train: {0}'.format(X_train.shape))
print('Size y_train: {0}'.format(y_train.shape))
print('Size X_test: {0}'.format(X_test.shape))

# show (pseudo-)random picture from the training data.
sample_idx = random.randint(0, X_train.shape[0])
sample = X_train[sample_idx]
plt.imshow(sample.reshape((28, 28)), cmap='Greys', interpolation='nearest')
plt.title('Handwritten number {0}'.format(y_train[sample_idx]))
plt.show()
# Out:
# Size X_train: (42000, 784)
# Size y_train: (42000,)
# Size X_test: (28000, 784)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# #### Rescaling

# %% [markdown]
# #### Splitting dataset

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15)

# %% [markdown]
# #### Reshaping

# %% [markdown]
# #### Data augmentation

# %%
scaler = preprocessing.StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# reshape vectors to one-hot
y_train = np_utils.to_categorical(y_train)
y_val = np_utils.to_categorical(y_val)

def reshape(m):
    """Reshape matrices to greyscale (so depth of 1) 2d images of 28 by 28 pixels."""
    return m.reshape(m.shape[0], 1, 28, 28).astype('float32')
# 
X_train = reshape(X_train)
X_val = reshape(X_val)
X_test = reshape(X_test)

# %%
# seq_blur = iaa.Sequential([iaa.GaussianBlur(sigma=(0, 3.0))]) # blur images with a sigma of 0 to 1.0
# seq_rotate = iaa.Sequential([iaa.Affine(
#     scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images to 80-120% of their size, individually per axis
#     translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)}, # translate by -20 to +20 percent (per axis)
#     shear=(-36, 36), # shear by -16 to +16 degrees
#     order=[0, 1], # use nearest neighbour or bilinear interpolation (fast)
# )])
# seq_crop = iaa.Sequential([iaa.Crop()])
# blurred_images = seq_blur.augment_images(X_train)
# rotated_images = seq_rotate.augment_images(X_train)
# cropped_images = seq_crop.augment_images(X_train)

# # sample may be in validation now
# if sample_idx > X_train.shape[0]:
#     sample_idx = random.randint(0, X_train.shape[0])

# # show the augmented picture derived from the sample
# blurred_sample = blurred_images[sample_idx]
# rotated_sample = rotated_images[sample_idx]
# cropped_sample = cropped_images[sample_idx]

# fig, axes = plt.subplots(2, 2)
# axes[0, 0].set_title('Blurred (Gaussian)')
# axes[0, 0].imshow(blurred_sample.reshape((28, 28)), cmap='Greys', interpolation='nearest')

# axes[0, 1].set_title('Rotated')
# axes[0, 1].imshow(rotated_sample.reshape((28, 28)), cmap='Greys', interpolation='nearest')

# axes[1, 0].set_title('Cropped')
# axes[1, 0].imshow(cropped_sample.reshape((28, 28)), cmap='Greys', interpolation='nearest')
# plt.show()

# %%
# save them to disk
# def save_set(data, path=''):
#     # reshape back
#     data = data.reshape(data.shape[0], 784).astype('float32')
#     data_set = pd.DataFrame(data=data)
#     data_set.to_csv(path+'test'+'.csv')
# save_set(blurred_images)

# %%
# X_train = np.concatenate([X_train, blurred_images, rotated_images])
# y_train = np.concatenate([y_train, y_train, y_train])
# # shuffle
# X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# ## Find the best network

# %%
# set variables
file_dir = './'
network_filepath = os.path.join(file_dir, 'best_model_mnist.h5')

nr_of_classes = y_train.shape[1]
epochs = 100
batch_size = 128
learning_rate = 1e-4
optimizer = Adam(lr=learning_rate)

# %%
def conv_model(nr_of_classes):
    inputs = Input(shape=(1, 28, 28))
    
    # layer 1
    x = Conv2D(32, (3, 3), data_format='channels_first')(inputs)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
#     x = Dropout(0.2)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # layer 2
    x = Conv2D(64, (3, 3))(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
#     x = Dropout(0.2)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # layer 3
    x = Conv2D(128, (3, 3))(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
#     x = Dropout(0.2)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Flatten()(x)
    x = Dense(256, kernel_initializer='he_normal')(x)
    x = LeakyReLU(alpha=0.1)(x)
#     x = Dropout(0.4)(x)
    predictions = Dense(nr_of_classes, kernel_initializer='he_normal', activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)
    print(model.summary())
    return model

# %%
# compile
model = conv_model(nr_of_classes)
model.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy']
)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 1, 28, 28)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 26, 26)        320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 26, 26)        104
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 26, 26)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 13, 26)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 11, 64)        15040
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 14, 11, 64)        256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 5, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 5, 3, 128)         512
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 5, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 1, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 158,450
# Trainable params: 158,014
# Non-trainable params: 436
# _________________________________________________________________
# None

# %% [markdown]
# ### Learning procedure

# %%
def train_network(network, X_train, y_train, X_val, y_val, epochs, batch_size, network_filepath):
    # lists where we will be storing values during training, for visualization purposes
    tra_losses = [] # list for training loss
    tra_accs = [] # list for training accuracy
    val_losses = [] # list for validation loss
    val_accs = [] # list for validation accuracy

    # we want to save the parameters that give the best performance on the validation set
    # therefore, we store the best validation accuracy, and save the parameters to disk
    best_validation_accuracy = 0 # best validation accuracy
    
    for epoch in range(epochs):
#         if epoch is 10:
#             optimizer.lr.set_value(int(learning_rate/2))
#         if epoch is 20:
#             optimizer.lr.set_value(int(learning_rate/4))
#         if epoch is 30:
#             optimizer.lr.set_value(int(learning_rate/8))
#         if epoch is 40:
#             optimizer.lr.set_value(int(learning_rate/16))
        st = time.time()

        # Train your network
        results = network.fit(X_train, y_train, batch_size=batch_size)

        # Get training loss and accuracy
        training_loss = results.history['loss']
        training_accuracy = results.history['acc']

        # Add to list
        tra_losses.append(training_loss)
        tra_accs.append(training_accuracy)

        # Evaluate performance (loss and accuracy) on validation set
        scores = network.evaluate(X_val, y_val, batch_size=batch_size)     
        validation_loss = scores[0]
        validation_accuracy = scores[1]

        # Add to list
        val_losses.append(validation_loss)
        val_accs.append(validation_accuracy)

        # (Possibly) update best validation accuracy and save the network
        if validation_accuracy > best_validation_accuracy:
            best_validation_accuracy = max(val_accs)
            network.save(network_filepath)

        # Visualization of the learning curves
        fig = plt.figure(figsize=(10, 5))
        tra_loss_plt, = plt.plot(range(len(tra_losses)), tra_losses, 'b')
        tra_accs_plt, = plt.plot(range(len(tra_accs)), tra_accs, 'c')
        val_loss_plt, = plt.plot(range(len(val_losses)), val_losses, 'g')
        val_acc_plt, = plt.plot(range(len(val_accs)), val_accs, 'r')
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.legend([tra_loss_plt, tra_accs_plt, val_loss_plt, val_acc_plt], 
                  ['training loss', 'training accuracy', 'validation loss', 'validation accuracy'],
                  loc='center left', bbox_to_anchor=(1, 0.5))
        plt.title('Best validation accuracy = {:.2f}%'.format(100. * best_validation_accuracy))
        display.clear_output(wait=True)
        display.display(plt.gcf())
        time.sleep(.2)

# %% [markdown]
# Scores:
#
# without dropout, lr = 0.0005 -> 98.48
#
# dropout - between all layers 0.2 -> 98.45
#
# dropout- all 0.2, last 0.4 - 0.15% test -> 98.41

# %%
train_network(model, X_train, y_train, X_val, y_val, epochs, batch_size, network_filepath)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f75f1651386a> in <module>()
# ----> 1 train_network(model, X_train, y_train, X_val, y_val, epochs, batch_size, network_filepath)
#
# <ipython-input-15-e577b25cd73f> in train_network(network, X_train, y_train, X_val, y_val, epochs, batch_size, network_filepath)
#      12     for epoch in range(epochs):
#      13         if epoch is 10:
# ---> 14             optimizer.lr.set_value(int(learning_rate/2))
#      15         if epoch is 20:
#      16             optimizer.lr.set_value(int(learning_rate/4))
#
# AttributeError: 'Variable' object has no attribute 'set_value'

# %% [markdown]
# # Classification

# %% [markdown]
# ## Train the full network

# %%
# use the total training set again
X_train = np.concatenate([X_train, X_val])
y_train = np.concatenate([y_train, y_val])

# shuffle the data sets
X_train, y_train = shuffle(X_train, y_train)

# train the best model
best_network = load_model(network_filepath)
# best_network.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

# %% [markdown]
# ### Test set classification

# %%
predictions = best_network.predict(X_test)
predictions = [np.argmax(sample_scores) for sample_scores in predictions]

# write to the results folder
write_results(predictions, RESULTS_FOLDER, 'conv_jup2_results')
